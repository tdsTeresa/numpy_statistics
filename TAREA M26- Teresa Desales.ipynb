# %%
#Importación de librerías para carga de csv y manejo de ditectorios
import csv
import os
cwd=os.getcwd()
print(cwd)
# Out:
# c:\Users\einzw

# %% [markdown]
# ### Cambio de directorio actual

# %%
#Cambio de directorio
os.chdir(r'C:\Users\einzw\Microsoft')

# %%
cwd=os.getcwd()
print(cwd)
# Out:
# C:\Users\einzw\Microsoft

# %% [markdown]
# ### Lectura del archivo .csv 'Height of Male and Female by Country 2022'

# %%
file=open(r'C:\Users\einzw\OneDrive\Escritorio\Ebac\Height of Male and Female by Country 2022.csv')
csvreader=csv.reader(file)

# %%
#comprobamos que el archivo se ha cargado en un objeto tipo csv.reader
type(csvreader)
# Out:
# _csv.reader

# %%
#Se almacena encabezado en nueva lista
head=[]
head=next(csvreader)
print(head)
# Out:
# ['Rank', 'Country Name', 'Male Height in Cm', 'Female Height in Cm', 'Male Height in Ft', 'Female Height in Ft']

# %%
#Se almacenan filas en nueva lista
rows=[]
for row in csvreader:
    rows.append(row)

# %%
#Importación de Numpy
import numpy as np

# %% [markdown]
# ### Imprimir las primeras 50 filas del dataset

# %%
#Almacenamos las filas en un array de Numpy 'heights'
heights=np.array(rows)

# %%
print(heights[:50])
# Out:
# [['1' 'Netherlands' '183.78' '170.36' '6.03' '5.59']
#  ['2' 'Montenegro' '183.30' '169.96' '6.01' '5.58']
#  ['3' 'Estonia' '182.79' '168.66' '6.00' '5.53']
#  ['4' 'Bosnia and Herzegovina' '182.47' '167.47' '5.99' '5.49']
#  ['5' 'Iceland' '182.10' '168.91' '5.97' '5.54']
#  ['6' 'Denmark' '181.89' '169.47' '5.97' '5.56']
#  ['7' 'Czech Republic' '181.19' '167.96' '5.94' '5.51']
#  ['8' 'Latvia' '181.17' '168.81' '5.94' '5.54']
#  ['9' 'Slovakia' '181.02' '167.12' '5.94' '5.48']
#  ['10' 'Slovenia' '180.98' '167.20' '5.94' '5.49']
#  ['11' 'Ukraine' '180.98' '166.62' '5.94' '5.47']
#  ['12' 'Croatia' '180.76' '166.80' '5.93' '5.47']
#  ['13' 'Serbia' '180.74' '168.29' '5.93' '5.52']
#  ['14' 'Lithuania' '180.72' '167.63' '5.93' '5.50']
#  ['15' 'Poland' '180.69' '165.78' '5.93' '5.44']
#  ['16' 'Finland' '180.57' '166.48' '5.92' '5.46']
#  ['17' 'Norway' '180.48' '166.45' '5.92' '5.46']
#  ['18' 'Sweden' '180.46' '166.67' '5.92' '5.47']
# ...

# %%
# Almacenamos valores numéricos (en cm y en pies) para su conversión
heights_cm=heights[:,2:4]
heights_ft=heights[:,4:]

# %%
# Altura en cm de la población
heights_cm[:3]
# Out:
# array([['183.78', '170.36'],
#        ['183.30', '169.96'],
#        ['182.79', '168.66']], dtype='<U32')

# %%
#Altura en cm de hombres y mujeres
heights_cm_male=heights_cm[:,:1]
heights_cm_female=heights_cm[:,1:]

# %%
print(heights_cm_male[:3])
# Out:
# [['183.78']
#  ['183.30']
#  ['182.79']]

# %%
print(heights_cm_female[:3])
# Out:
# [['170.36']
#  ['169.96']
#  ['168.66']]

# %%
#Altura de la población en pies
heights_ft[:3]
# Out:
# array([['6.03', '5.59'],
#        ['6.01', '5.58'],
#        ['6.00', '5.53']], dtype='<U32')

# %%
# Se comprueba el tipo de dato de las nuevas variables
type(heights_cm)
# Out:
# numpy.ndarray

# %%
type(heights_ft)
# Out:
# numpy.ndarray

# %%
#Transformamos cada variable en un array unidimensional, para poder realizar los cálculos estadísticos
heights_cm_plano=heights_cm.flatten()

# %%
heights_male_plano=heights_cm_male.flatten()

# %%
heights_female_plano=heights_cm_female.flatten()

# %%
heights_ft_plano=heights_ft.flatten()

# %%
heights_cm_plano.shape
# Out:
# (398,)

# %%
heights_male_plano.shape
# Out:
# (199,)

# %%
heights_female_plano.shape
# Out:
# (199,)

# %%
heights_ft_plano.shape
# Out:
# (398,)

# %%
#Conversión de cada item de los nuevos arrays a tipo flotante
heights_cm_plano=[float(num) for num in heights_cm_plano]

# %%
heights_male_plano=[float(num) for num in heights_male_plano]
heights_female_plano=[float(num) for num in heights_female_plano]

# %%
heights_ft_plano=[float(num) for num in heights_ft_plano]

# %%
print(heights_cm_plano)
# Out:
# [183.78, 170.36, 183.3, 169.96, 182.79, 168.66, 182.47, 167.47, 182.1, 168.91, 181.89, 169.47, 181.19, 167.96, 181.17, 168.81, 181.02, 167.12, 180.98, 167.2, 180.98, 166.62, 180.76, 166.8, 180.74, 168.29, 180.72, 167.63, 180.69, 165.78, 180.57, 166.48, 180.48, 166.45, 180.46, 166.67, 180.28, 166.18, 180.15, 166.89, 179.72, 166.11, 179.48, 163.06, 179.26, 165.81, 179.09, 163.4, 179.04, 164.5, 178.96, 163.67, 178.84, 165.53, 178.84, 165.72, 178.77, 164.67, 178.75, 164.73, 178.73, 164.33, 178.7, 165.99, 178.69, 166.93, 178.6, 164.49, 178.52, 166.93, 178.46, 165.07, 178.32, 167.31, 178.32, 166.52, 178.21, 163.94, 177.82, 164.73, 177.72, 164.66, 177.49, 165.3, 177.19, 167.03, 177.09, 167.55, 177.03, 165.66, 176.97, 164.32, 176.94, 163.31, 176.85, 161.69, 176.65, 164.52, 176.59, 162.55, 176.43, 165.52, 176.43, 160.88, 176.39, 162.56, 176.36, 161.8, 176.35, 161.18, 176.18, 163.92, 176.11, 162.03, 176.06, 166.08, 176.03, 163.38, 175.98, 162.22, 175.98, 163.24, 175.9, 162.47, 175.73, 162.41, 
# ...

# %%
print(heights_male_plano)
# Out:
# [183.78, 183.3, 182.79, 182.47, 182.1, 181.89, 181.19, 181.17, 181.02, 180.98, 180.98, 180.76, 180.74, 180.72, 180.69, 180.57, 180.48, 180.46, 180.28, 180.15, 179.72, 179.48, 179.26, 179.09, 179.04, 178.96, 178.84, 178.84, 178.77, 178.75, 178.73, 178.7, 178.69, 178.6, 178.52, 178.46, 178.32, 178.32, 178.21, 177.82, 177.72, 177.49, 177.19, 177.09, 177.03, 176.97, 176.94, 176.85, 176.65, 176.59, 176.43, 176.43, 176.39, 176.36, 176.35, 176.18,
5.39, 5.81, 5.36, 5.8, 5.3, 5.8, 5.4, 5.79, 5.33, 5.79, 5.43, 5.79, 5.28, 5.79, 5.33, 5.79, 5.31, 5.79, 5.29, 5.78, 5.38, 5.78, 5.32, 5.78, 5.45, 5.78, 5.36, 5.77, 5.32, 5.77, 5.36, 5.77, 5.33, 5.77, 5.33, 5.76, 5.36, 5.76, 5.29, 5.76, 5.35, 5.76, 5.36, 5.76, 5.31, 5.75, 5.45, 5.74, 5.29, 5.74, 5.33, 5.74, 5.31, 5.74, 5.25, 5.74, 5.23, 5.74, 5.27, 5.73, 5.29, 5.73, 5.29, 5.73, 5.29, 5.73, 5.28, 5.73, 5.32, 5.72, 5.31, 5.72, 5.37, 5.72, 5.36, 5.72, 5.35, 5.7
# ...

# %%
#Importación de la función 'mean' del módulo estadístico para realizar los cálculos en cm
from statistics import mean
heights_cm_mean=mean(heights_cm_plano)
heights_male=mean(heights_male_plano)
heights_female=mean(heights_female_plano)
heights_cm_min=min(heights_cm_plano)
heights_cm_max=max(heights_cm_plano)

#Cálculos en pies
heights_ftmean=mean(heights_ft_plano)
heights_ft_min=min(heights_ft_plano)
heights_ft_max=max(heights_ft_plano)

# %%
print('Estatura mínima: ', float(heights_cm_min))
print('Estatura máxima: ', float(heights_cm_max))
# Out:
# Estatura mínima:  150.91
# Estatura máxima:  183.78

# %%
print(heights[:3])
# Out:
# [['1' 'Netherlands' '183.78' '170.36' '6.03' '5.59']
#  ['2' 'Montenegro' '183.30' '169.96' '6.01' '5.58']
#  ['3' 'Estonia' '182.79' '168.66' '6.00' '5.53']]

# %%
#Buscamos los datos de los países con la estatura mínima y máxima del dataset original 'heights', en la tercera y segunda columna
filter_cm_min=heights[heights[:,3]=='150.91']
print(filter_cm_min)
# Out:
# [['194' 'Guatemala' '164.36' '150.91' '5.39' '4.95']]

# %%
filter_cm_max=heights[heights[:,2]=='183.78']
print(filter_cm_max)
# Out:
# [['1' 'Netherlands' '183.78' '170.36' '6.03' '5.59']]

# %% [markdown]
# ### Resumen estadístico (media, valor mínimo y máximo)

# %%
print('En 2022 la estatura promedio de la población adulta en general fue de ', ('{:.2f}'.format(float(heights_cm_mean))),'cm, es decir ',  ('{:.2f}'.format(float(heights_ftmean))), 'pies.')
print('La estatura promedio para hombres fue de ', ('{:.2f}'.format(float(heights_male))),'cm ', 'mientras que para las mujeres fue de', ('{:.2f}'.format(float(heights_female))), ' cm.')
print('La estatura promedio mínima fue de ', float(heights_cm_min),'cm ', '(', float(heights_ft_min), ' pies), que corresponde a las mujeres en Guatemala.')
print('La estatura promedio máxima fue de ', float(heights_cm_max),'cm ', '(', float(heights_ft_max), ' pies), que corresponde a los hombres en Países Bajos.')
# Out:
# En 2022 la estatura promedio de la población adulta en general fue de  167.02 cm, es decir  5.48 pies.
# La estatura promedio para hombres fue de  173.09 cm  mientras que para las mujeres fue de 160.94  cm.
# La estatura promedio mínima fue de  150.91 cm  ( 4.95  pies), que corresponde a las mujeres en Guatemala.
# La estatura promedio máxima fue de  183.78 cm  ( 6.03  pies), que corresponde a los hombres en Países Bajos.

# %%
#Filtro de país en el dataset original 'heights'
pais=heights[:,1]
print(pais)
# Out:
# ['Netherlands' 'Montenegro' 'Estonia' 'Bosnia and Herzegovina' 'Iceland'
#  'Denmark' 'Czech Republic' 'Latvia' 'Slovakia' 'Slovenia' 'Ukraine'
#  'Croatia' 'Serbia' 'Lithuania' 'Poland' 'Finland' 'Norway' 'Sweden'
#  'Germany' 'Dominica' 'Bermuda' 'Puerto Rico' 'Greece' 'Belgium' 'Ireland'
#  'Lebanon' 'Andorra' 'Antigua and Barbuda' 'Australia' 'Canada'
#  'Switzerland' 'Grenada' 'Belarus' 'France' 'Austria' 'Luxembourg'
#  'Cook Islands' 'French Polynesia' 'United Kingdom' 'Romania'
#  'New Zealand' 'Saint Vincent and the Grenadines' 'Niue' 'American Samoa'
#  'Barbados' 'Jamaica' 'United States' 'Tunisia' 'Russia' 'Hungary'
#  'Saint Lucia' 'North Macedonia' 'Libya' 'Turkey' 'Morocco' 'Senegal'
#  'Spain' 'Tokelau' 'Trinidad and Tobago' 'Israel' 'Georgia' 'Seychelles'
#  'Brazil' 'China' 'Iran' 'Moldova' 'South Korea' 'Kazakhstan' 'Tonga'
#  'Palestine' 'Algeria' 'Mali' 'Kuwait' 'Jordan' 'Hong Kong' 'Argentina'
# ...

# %%
filter_pais=(pais=='Mexico')
filter_mexico=heights[filter_pais]
print(filter_mexico)
# Out:
# [['139' 'Mexico' '170.29' '157.90' '5.59' '5.18']]

# %%
#Se obtienen sólo valores numéricos
mexico=filter_mexico[:, 2:]
print(mexico)
# Out:
# [['170.29' '157.90' '5.59' '5.18']]

# %%
#Damos formato plano y de lista al array
mexico_lista=mexico.flatten().tolist()
print(mexico_lista)
# Out:
# ['170.29', '157.90', '5.59', '5.18']

# %%
type(mexico_lista)
# Out:
# list

# %%
#Conversión a valores a flotantes
mexico_lista_float=[float(num) for  num in mexico_lista]
print(mexico_lista_float)
# Out:
# [170.29, 157.9, 5.59, 5.18]

# %%
#Obtenemos los valores en cm y en pies
mexico_cm=mexico_lista_float[:2]
mexico_ft=mexico_lista_float[2:]

# %%
print(mexico_cm)
# Out:
# [170.29, 157.9]

# %%
print(mexico_ft)
# Out:
# [5.59, 5.18]

# %%
#Media de los valores
mexico_mean_cm=mean(mexico_cm)
mexico_mean_ft=mean(mexico_ft)

# %% [markdown]
# ### Resumen estadístico para México

# %%
print('En México, en 2022 la estatura promedio de la población adulta en general fue de ', ('{:.2f}'.format(float(mexico_mean_cm))),'cm, es decir ',  ('{:.2f}'.format(float(mexico_mean_ft))), 'pies,')
print('170.29 cm y 157.9 cm para hombres y mujeres respectivamente.')
# Out:
# En México, en 2022 la estatura promedio de la población adulta en general fue de  164.09 cm, es decir  5.38 pies,
# 170.29 cm y 157.9 cm para hombres y mujeres respectivamente.
